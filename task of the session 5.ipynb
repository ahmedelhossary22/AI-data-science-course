# %%
rows = 5
cols =9
mid = cols//2
for i in range (rows):
    for j in range(cols):
        if j==0 or j==cols-1 or i==0 or i==rows-1 or j==mid:
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# * * * * * * * * *
# *       *       *
# *       *       *
# *       *       *
# * * * * * * * * *
